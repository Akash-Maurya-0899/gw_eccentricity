# %%
import gw_eccentricity as ge
from gwnr.waveform import esigma_utils as eu
import matplotlib.pyplot as plt
# Out:
# lal.MSUN_SI != Msun
# setting __package__ to gwsurrogate.new so relative imports work
# __name__ = gwsurrogate.new.spline_evaluation
# __package__= gwsurrogate.new
# setting __package__ to gwsurrogate.new so relative imports work
# setting __package__ to gwsurrogate.new so relative imports work
# /home/akash-x16/anaconda3/envs/enigma-py38/lib/python3.8/site-packages/gwtools/rotations.py:63: UserWarning: Could not import GWFrames, needed for rotations module
#   _warnings.warn("Could not import GWFrames, needed for rotations module")
# /home/akash-x16/anaconda3/envs/enigma-py38/lib/python3.8/site-packages/gwtools/__init__.py:11: UserWarning: Could not import rotations, decompositions, or fitfuncs. These are not needed by GWSurrogate.
#   _warnings.warn("Could not import rotations, decompositions, or fitfuncs. These are not needed by GWSurrogate.")

# %%
M = 10.
qq = 1.
f_s = 2.0**14  # Sampling frequency
modes_to_use = [(2, 2)]
orbital_params_to_use = ["x", "e", "l"]
f_low = 19.4

e0 = 0.0
mean_anomaly = 0.0

t_grid0, orb_vars0, mode0 = eu.get_inspiral_esigma_modes(
    mass1=qq * M / (1 + qq),
    mass2=M / (1 + qq),
    eccentricity=e0,
    mean_anomaly=mean_anomaly,
    f_lower=f_low,
    delta_t=1/f_s,
    modes_to_use=modes_to_use,
    return_orbital_params=orbital_params_to_use,
    include_conjugate_modes=False,
    return_pycbc_timeseries=False,
    verbose=False,
)

e0 = 0.25
mean_anomaly = 0.3

t_grid, orb_vars, mode = eu.get_inspiral_esigma_modes(
    mass1=qq * M / (1 + qq),
    mass2=M / (1 + qq),
    eccentricity=e0,
    mean_anomaly=mean_anomaly,
    f_lower=f_low,
    delta_t=1/f_s,
    modes_to_use=modes_to_use,
    return_orbital_params=orbital_params_to_use,
    include_conjugate_modes=False,
    return_pycbc_timeseries=False,
    verbose=False,
)

# %%
# t_grid0 = mode0[str(mode_name)].sample_times.data
# t_peak_circular = find_t_location(t_grid0, orb_vars0['x'].data, x_final) # Finding time where "x" reaches its ISCO-value

# h_p0, h_c0 = pol_from_modes(mode0, mode_name)
# t_grid0 -= t_peak_circular # Setting t=0 at ISCO
# amp0, phase0 = amp_phase_decompose(h_p0, h_c0)
# print(f"Found ISCO frequency at t=0, {cubic_interp(0, t_grid0, orb_vars0['x'].data**1.5/(M*lal.PI*lal.MTSUN_SI))}Hz")

# index=498
# print(params[index])
# """
# Returns the time at which the amplitude peaks, and the min and max value of time 
# for each waveform after they have been aligned s.t. amplitud peak occurs at t=0
# """
# waveform_filename = f"waveform_{index}.hdf"
# mode = read_data(directory+"/"+waveform_filename)
# orb_vars = read_data(directory+"/"+waveform_filename, hdf_group="orbital_vars")
# h_p, h_c = pol_from_modes(mode, mode_name)
# t_grid = h_p.sample_times.data

# # Setting t_peak to where "x" reaches its ISCO-value
# t_peak = find_t_location(t_grid, orb_vars['x'].data, x_final)
# t_grid -= t_peak #Aligning the waveforms by amplitude
# amp = amp_phase_decompose(h_p, h_c, amp_only=True)

# # Subtracting the circular pieces
# amp_data0 = resample_data(t_new=1*t_grid, t_old=1*t_grid0, data=1*amp0.data)
# delta_amp = amp - amp_data0

# %%
# %matplotlib notebook
plt.plot(t_grid0, mode0[(2,2)])
plt.plot(t_grid, mode[(2,2)])
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">
# /home/akash-x16/anaconda3/envs/enigma-py38/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /home/akash-x16/anaconda3/envs/enigma-py38/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
dataDict = {"t": t_grid,
            "hlm":{(2,2): mode[(2, 2)].data},
            "t_zeroecc": t_grid0,
            "hlm_zeroecc": {(2,2): mode0[(2, 2)].data}}

#     try:
#         return_dict = ge.measure_eccentricity(tref_in=tref_in,
#                                           method=method,
#                                           dataDict=dataDict)
#         tref_out = return_dict["tref_out"]
#         e_ref = return_dict["eccentricity"]
#         l_ref = return_dict["mean_anomaly"]
#         gwecc_object = return_dict['gwecc_object']
#         Mf_per_low = gwecc_object.omega22_pericenters_interp(tref_in)/(2*np.pi)
#         print(f"method = {method:20s} eccentricity = {e_ref:.6f}, mean anomaly = {l_ref:.4f}, f_per_low = {Mf_per_low/(M*t0.value):.2f} Hz, t_ref out = {tref_out:.2f}")

#     except:
#         print (f"Couldn't get the eccentricity: i = {i}")

tref_in = -15.0

ge_kwargs = {"debug_level": 1,
            "inspiral_only": True}

return_dict = ge.measure_eccentricity(tref_in=tref_in,
                                  method="ResidualAmplitude",
                                  dataDict=dataDict,
                                  num_orbits_to_exclude_before_merger = None,
                                  extra_kwargs=ge_kwargs
                                     )

tref_out = return_dict["tref_out"]
e_ref = return_dict["eccentricity"]
l_ref = return_dict["mean_anomaly"]
gwecc_object = return_dict['gwecc_object']

# Mf_per_low = gwecc_object.omega22_pericenters_interp(tref_in)/(2*np.pi)
# Out:
# /mnt/c/AKASH/git-repositories/github/gw_eccentricity/gw_eccentricity/eccDefinition.py:1935: UserWarning: egw(t) is nonmonotonic in the range [-0.04101562500000355, -0.006774902343753553]
#   debug_message(message, self.debug_level, point_to_verbose_output=True)

# %%
gwecc_object.t_merger, gwecc_object.t_merger_zeroecc
# Out:
# (0.0, 0.0)

# %%
t_grid[-1], t_grid0[-1]
# Out:
# (0.0, 0.0)
